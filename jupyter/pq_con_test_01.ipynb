# %%
import psycopg2

# %%
conn = psycopg2.connect('host=192.168.0.36 dbname=stock-explorer user=postgres password=postgres')

cur = conn.cursor()

# %%
sql = 'SELECT * FROM ticker'
cur.execute(sql)
results = cur.fetchall()
for line in results:
    print(line)
# Out:
# (9, 20240430, '1381', 'アクシーズ', 'スタンダード（内国株式）', 50, '水産・農林業', 1, '食品', '-', '-')
# (10, 20240430, '1382', 'ホーブ', 'スタンダード（内国株式）', 50, '水産・農林業', 1, '食品', '-', '-')
# (11, 20240430, '1383', 'ベルグアース', 'スタンダード（内国株式）', 50, '水産・農林業', 1, '食品', '-', '-')
# (12, 20240430, '1384', 'ホクリヨウ', 'スタンダード（内国株式）', 50, '水産・農林業', 1, '食品', '7', 'TOPIX Small 2')
# (14, 20240430, '1401', 'エムビーエス', 'グロース（内国株式）', 2050, '建設業', 3, '建設・資材', '-', '-')
# (15, 20240430, '1407', 'ウエストホールディングス', 'スタンダード（内国株式）', 2050, '建設業', 3, '建設・資材', '-', '-')
# (16, 20240430, '1414', 'ショーボンドホールディングス', 'プライム（内国株式）', 2050, '建設業', 3, '建設・資材', '4', 'TOPIX Mid400')
# (17, 20240430, '1417', 'ミライト・ワン', 'プライム（内国株式）', 2050, '建設業', 3, '建設・資材', '4', 'TOPIX Mid400')
# (18, 20240430, '1418', 'インターライフホールディングス', 'スタンダード（内国株式）', 2050, '建設業', 3, '建設・資材', '-', '-')
# (19, 20240430, '1419', 'タマホーム', 'プライム（内国株式）', 2050, '建設業', 3, '建設・資材', '6', 'TOPIX Small 1')
# ...
