# %%
import os

os.chdir('../')
os.getcwd()
# Out:
# '/home/bitwalk/MyProjects/stock-explorer-postgres'

# %%
import pandas as pd
from funcs.common import get_excel_from_url

tse = 'https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls'
list_market = [
    'グロース（内国株式）',
    'スタンダード（内国株式）',
    'プライム（内国株式）',
]
df_all = get_excel_from_url(tse)
df_all
# Out:
# 100% [........................................................] 797696 / 797696
#             日付   コード                                   銘柄名       市場・商品区分  \
# 0     20231130  1301                                    極洋    プライム（内国株式）
# 1     20231130  1305                ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）       ETF・ETN
# 2     20231130  1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信       ETF・ETN
# 3     20231130  1308                     上場インデックスファンドＴＯＰＩＸ       ETF・ETN
# 4     20231130  1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信       ETF・ETN
# ...        ...   ...                                   ...           ...
# 4318  20231130  9993                                  ヤマザワ  スタンダード（内国株式）
# 4319  20231130  9994                                   やまや  スタンダード（内国株式）
# 4320  20231130  9995                                 グローセル    プライム（内国株式）
# 4321  20231130  9996                                 サトー商会  スタンダード（内国株式）
# 4322  20231130  9997                                  ベルーナ    プライム（内国株式）
#
#      33業種コード  33業種区分 17業種コード  17業種区分 規模コード           規模区分
# 0         50  水産・農林業       1     食品      7  TOPIX Small 2
# 1          -       -       -       -     -              -
# 2          -       -       -       -     -              -
# 3          -       -       -       -     -              -
# 4          -       -       -       -     -              -
# ...      ...     ...     ...     ...   ...            ...
# 4318    6100     小売業      14     小売      7  TOPIX Small 2
# 4319    6100     小売業      14     小売      7  TOPIX Small 2
# 4320    6050     卸売業      13  商社・卸売      7  TOPIX Small 2
# 4321    6050     卸売業      13  商社・卸売      -              -
# 4322    6100     小売業      14     小売      6  TOPIX Small 1
#
# [4323 rows x 10 columns]

# %%
df_stock0 = df_all[df_all['市場・商品区分'].isin(list_market)]
df_stock = df_stock0[[len(str(p)) == 4 for p in df_stock0['コード']]].reset_index(drop=True)
df_stock['コード'] = df_stock['コード'].astype(str)
df_stock
# Out:
#             日付   コード     銘柄名       市場・商品区分 33業種コード  33業種区分 17業種コード  17業種区分  \
# 0     20231130  1301      極洋    プライム（内国株式）      50  水産・農林業       1     食品
# 1     20231130  1332    ニッスイ    プライム（内国株式）      50  水産・農林業       1     食品
# 2     20231130  1333  マルハニチロ    プライム（内国株式）      50  水産・農林業       1     食品
# 3     20231130  1375  雪国まいたけ    プライム（内国株式）      50  水産・農林業       1     食品
# 4     20231130  1376   カネコ種苗  スタンダード（内国株式）      50  水産・農林業       1     食品
# ...        ...   ...     ...           ...     ...     ...     ...     ...
# 3822  20231130  9993    ヤマザワ  スタンダード（内国株式）    6100     小売業      14     小売
# 3823  20231130  9994     やまや  スタンダード（内国株式）    6100     小売業      14     小売
# 3824  20231130  9995   グローセル    プライム（内国株式）    6050     卸売業      13  商社・卸売
# 3825  20231130  9996   サトー商会  スタンダード（内国株式）    6050     卸売業      13  商社・卸売
# 3826  20231130  9997    ベルーナ    プライム（内国株式）    6100     小売業      14     小売
#
#      規模コード           規模区分
# 0        7  TOPIX Small 2
# 1        4   TOPIX Mid400
# 2        4   TOPIX Mid400
# 3        7  TOPIX Small 2
# 4        7  TOPIX Small 2
# ...    ...            ...
# 3822     7  TOPIX Small 2
# 3823     7  TOPIX Small 2
# 3824     7  TOPIX Small 2
# 3825     -              -
# 3826     6  TOPIX Small 1
#
# [3827 rows x 10 columns]
