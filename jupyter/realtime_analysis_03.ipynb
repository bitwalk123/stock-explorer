# %%
import datetime
import matplotlib.pyplot as plt
from matplotlib import dates
import pandas as pd

# %%
pkl = '../tmp/8035_2024-05-31.pkl'

# %%
df = pd.read_pickle(pkl)
df
# Out:
#                        Price
# 2024-05-31 09:00:03  34040.0
# 2024-05-31 09:00:08  34050.0
# 2024-05-31 09:00:14  34020.0
# 2024-05-31 09:00:20  34010.0
# 2024-05-31 09:00:26  34000.0
# ...                      ...
# 2024-05-31 14:59:38  33680.0
# 2024-05-31 14:59:43  33660.0
# 2024-05-31 14:59:50  33660.0
# 2024-05-31 14:59:57  33650.0
# 2024-05-31 15:00:00  33630.0
#
# [2427 rows x 1 columns]

# %%
dt = datetime.datetime.today()  # ローカルな現在の日付と時刻を取得
print(dt)  # 2021-10-29 15:58:08.356501
print('%4d-%02d-%02d' % (dt.year, dt.month, dt.day))
# Out:
# 2024-06-01 07:39:48.774697
# 2024-06-01

# %%
date_str = str(df.index[0].date())
time_left = pd.to_datetime(date_str + ' 08:50:00')
time_mid = pd.to_datetime(date_str + ' 12:00:00')
time_right = pd.to_datetime(date_str + ' 15:10:00')
print(time_left, time_mid, time_right)
# Out:
# 2024-05-31 08:50:00 2024-05-31 12:00:00 2024-05-31 15:10:00

# %%
df1 = df.loc[df.index[df.index < time_mid]]
df2 = df.loc[df.index[df.index > time_mid]]

# %%
plt.rcParams["figure.figsize"] = (10, 4)
fig, ax = plt.subplots()

ax.plot(df1, c='C0')
ax.plot(df2, c='C0')
ax.set_xlim(time_left, time_right)

plt.gca().xaxis.set_major_formatter(dates.DateFormatter('%H:%M'))
plt.grid()
plt.show()

# %%
df.tail(1)
# Out:
#                        Price
# 2024-05-24 15:00:00  35790.0
