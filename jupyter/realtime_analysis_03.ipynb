# %%
import datetime
import matplotlib.pyplot as plt
from matplotlib import dates
import pandas as pd

# %%
pkl = '../tmp/8035_2024-05-21.pkl'

# %%
df = pd.read_pickle(pkl)
df
# Out:
#                        Price
# 2024-05-21 09:00:07  36660.0
# 2024-05-21 09:00:18  36610.0
# 2024-05-21 09:00:28  36630.0
# 2024-05-21 09:00:37  36640.0
# 2024-05-21 09:00:46  36640.0
# ...                      ...
# 2024-05-21 14:59:28  36560.0
# 2024-05-21 14:59:37  36590.0
# 2024-05-21 14:59:48  36590.0
# 2024-05-21 14:59:59  36600.0
# 2024-05-21 15:00:00  36630.0
#
# [1552 rows x 1 columns]

# %%
date_str = str(df.index[0].date())
time_left = pd.to_datetime(date_str + ' 08:50:00')
time_mid = pd.to_datetime(date_str + ' 12:00:00')
time_right = pd.to_datetime(date_str + ' 15:10:00')
print(time_left, time_mid, time_right)
# Out:
# 2024-05-21 08:50:00 2024-05-21 12:00:00 2024-05-21 15:10:00

# %%
df1 = df.loc[df.index[df.index < time_mid]]
df2 = df.loc[df.index[df.index > time_mid]]

# %%
plt.rcParams["figure.figsize"] = (10, 4)
fig, ax = plt.subplots()

ax.plot(df1, c='C0')
ax.plot(df2, c='C0')
ax.set_xlim(time_left, time_right)

plt.gca().xaxis.set_major_formatter(dates.DateFormatter('%H:%M'))
plt.grid()
plt.show()
