# %%
import datetime as dt
import mplfinance as mpf
import numpy as np
import pandas as pd
import yfinance as yf
from zoneinfo import ZoneInfo

# %%
ticker = yf.Ticker('8035.T')

# %%
end = dt.datetime.now(dt.timezone(dt.timedelta(hours=9)))
delta = dt.timedelta(hours=6)
start = end - delta

#df = ticker.history(start=start, end=end, interval='1m')
df = ticker.history(period='1d', interval='1m')
#df.to_pickle('8035_20240911_1m.pkl')
df
# Out:
#                               Open     High      Low    Close  Volume  \
# Datetime
# 2024-09-11 09:00:00+09:00  22230.0  22365.0  22170.0  22340.0       0
# 2024-09-11 09:01:00+09:00  22340.0  22570.0  22340.0  22525.0   75200
# 2024-09-11 09:02:00+09:00  22540.0  22650.0  22530.0  22615.0   55500
# 2024-09-11 09:03:00+09:00  22615.0  22630.0  22465.0  22480.0   53500
# 2024-09-11 09:04:00+09:00  22475.0  22510.0  22400.0  22465.0   55200
# ...                            ...      ...      ...      ...     ...
# 2024-09-11 14:55:00+09:00  22220.0  22245.0  22215.0  22240.0   18800
# 2024-09-11 14:56:00+09:00  22245.0  22270.0  22220.0  22230.0   35100
# 2024-09-11 14:57:00+09:00  22225.0  22240.0  22210.0  22235.0   23300
# 2024-09-11 14:58:00+09:00  22235.0  22235.0  22210.0  22225.0   20500
# 2024-09-11 14:59:00+09:00  22220.0  22235.0  22175.0  22175.0   48000
#
#                            Dividends  Stock Splits
# Datetime
# 2024-09-11 09:00:00+09:00        0.0           0.0
# 2024-09-11 09:01:00+09:00        0.0           0.0
# 2024-09-11 09:02:00+09:00        0.0           0.0
# 2024-09-11 09:03:00+09:00        0.0           0.0
# 2024-09-11 09:04:00+09:00        0.0           0.0
# ...                              ...           ...
# 2024-09-11 14:55:00+09:00        0.0           0.0
# 2024-09-11 14:56:00+09:00        0.0           0.0
# 2024-09-11 14:57:00+09:00        0.0           0.0
# 2024-09-11 14:58:00+09:00        0.0           0.0
# 2024-09-11 14:59:00+09:00        0.0           0.0
#
# [302 rows x 7 columns]

# %%
df.index.name
# Out:
# 'Datetime'

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
mpf.plot(df, type='candle', style='binance', ylabel='USD - JPY', figratio=(12, 4))

# %%
dt_now = dt.datetime.now(ZoneInfo("Asia/Tokyo"))
dt_now
# Out:
# datetime.datetime(2024, 9, 12, 6, 46, 11, 929780, tzinfo=zoneinfo.ZoneInfo(key='Asia/Tokyo'))

# %%
y = dt_now.year
m = dt_now.month
d = dt_now.day
dt_start_1 = pd.to_datetime('%4d-%02d-%02d 09:00:00+09:00' % (y, m, d))
dt_end_1 = pd.to_datetime('%4d-%02d-%02d 11:30:00+09:00' % (y, m, d))

dt_start_2 = pd.to_datetime('%4d-%02d-%02d 12:30:00+09:00' % (y, m, d))
dt_end_2 = pd.to_datetime('%4d-%02d-%02d 15:00:00+09:00' % (y, m, d))

# %%
df[df.index <= dt_end_1]
# Out:
#                               Open     High      Low    Close  Volume  \
# Datetime
# 2024-09-11 09:00:00+09:00  22230.0  22365.0  22170.0  22340.0       0
# 2024-09-11 09:01:00+09:00  22340.0  22570.0  22340.0  22525.0   75200
# 2024-09-11 09:02:00+09:00  22540.0  22650.0  22530.0  22615.0   55500
# 2024-09-11 09:03:00+09:00  22615.0  22630.0  22465.0  22480.0   53500
# 2024-09-11 09:04:00+09:00  22475.0  22510.0  22400.0  22465.0   55200
# ...                            ...      ...      ...      ...     ...
# 2024-09-11 14:55:00+09:00  22220.0  22245.0  22215.0  22240.0   18800
# 2024-09-11 14:56:00+09:00  22245.0  22270.0  22220.0  22230.0   35100
# 2024-09-11 14:57:00+09:00  22225.0  22240.0  22210.0  22235.0   23300
# 2024-09-11 14:58:00+09:00  22235.0  22235.0  22210.0  22225.0   20500
# 2024-09-11 14:59:00+09:00  22220.0  22235.0  22175.0  22175.0   48000
#
#                            Dividends  Stock Splits
# Datetime
# 2024-09-11 09:00:00+09:00        0.0           0.0
# 2024-09-11 09:01:00+09:00        0.0           0.0
# 2024-09-11 09:02:00+09:00        0.0           0.0
# 2024-09-11 09:03:00+09:00        0.0           0.0
# 2024-09-11 09:04:00+09:00        0.0           0.0
# ...                              ...           ...
# 2024-09-11 14:55:00+09:00        0.0           0.0
# 2024-09-11 14:56:00+09:00        0.0           0.0
# 2024-09-11 14:57:00+09:00        0.0           0.0
# 2024-09-11 14:58:00+09:00        0.0           0.0
# 2024-09-11 14:59:00+09:00        0.0           0.0
#
# [302 rows x 7 columns]

# %%
df[df.index >= dt_start_2]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Dividends, Stock Splits]
# Index: []

# %%
df[(df.index <= dt_end_1) | (df.index >= dt_start_2)]
# Out:
#                               Open     High      Low    Close  Volume  \
# Datetime
# 2024-09-11 09:00:00+09:00  22230.0  22365.0  22170.0  22340.0       0
# 2024-09-11 09:01:00+09:00  22340.0  22570.0  22340.0  22525.0   75200
# 2024-09-11 09:02:00+09:00  22540.0  22650.0  22530.0  22615.0   55500
# 2024-09-11 09:03:00+09:00  22615.0  22630.0  22465.0  22480.0   53500
# 2024-09-11 09:04:00+09:00  22475.0  22510.0  22400.0  22465.0   55200
# ...                            ...      ...      ...      ...     ...
# 2024-09-11 14:55:00+09:00  22220.0  22245.0  22215.0  22240.0   18800
# 2024-09-11 14:56:00+09:00  22245.0  22270.0  22220.0  22230.0   35100
# 2024-09-11 14:57:00+09:00  22225.0  22240.0  22210.0  22235.0   23300
# 2024-09-11 14:58:00+09:00  22235.0  22235.0  22210.0  22225.0   20500
# 2024-09-11 14:59:00+09:00  22220.0  22235.0  22175.0  22175.0   48000
#
#                            Dividends  Stock Splits
# Datetime
# 2024-09-11 09:00:00+09:00        0.0           0.0
# 2024-09-11 09:01:00+09:00        0.0           0.0
# 2024-09-11 09:02:00+09:00        0.0           0.0
# 2024-09-11 09:03:00+09:00        0.0           0.0
# 2024-09-11 09:04:00+09:00        0.0           0.0
# ...                              ...           ...
# 2024-09-11 14:55:00+09:00        0.0           0.0
# 2024-09-11 14:56:00+09:00        0.0           0.0
# 2024-09-11 14:57:00+09:00        0.0           0.0
# 2024-09-11 14:58:00+09:00        0.0           0.0
# 2024-09-11 14:59:00+09:00        0.0           0.0
#
# [302 rows x 7 columns]

# %%
dt_list_0 = pd.date_range(dt_start_1, periods=360, freq='min')
len(dt_list_0)
# Out:
# 360

# %%
dt_list = dt_list_0[(dt_list_0 <= dt_end_1) | (dt_list_0 >= dt_start_2)]
n = len(dt_list)
dt_list
# Out:
# DatetimeIndex(['2024-09-12 09:00:00+09:00', '2024-09-12 09:01:00+09:00',
#                '2024-09-12 09:02:00+09:00', '2024-09-12 09:03:00+09:00',
#                '2024-09-12 09:04:00+09:00', '2024-09-12 09:05:00+09:00',
#                '2024-09-12 09:06:00+09:00', '2024-09-12 09:07:00+09:00',
#                '2024-09-12 09:08:00+09:00', '2024-09-12 09:09:00+09:00',
#                ...
#                '2024-09-12 14:50:00+09:00', '2024-09-12 14:51:00+09:00',
#                '2024-09-12 14:52:00+09:00', '2024-09-12 14:53:00+09:00',
#                '2024-09-12 14:54:00+09:00', '2024-09-12 14:55:00+09:00',
#                '2024-09-12 14:56:00+09:00', '2024-09-12 14:57:00+09:00',
#                '2024-09-12 14:58:00+09:00', '2024-09-12 14:59:00+09:00'],
#               dtype='datetime64[ns, UTC+09:00]', length=301, freq=None)

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
pd.NA

# %%
df0 = pd.DataFrame(
    {
        'Open': [np.nan] * n,
        'High': [np.nan] * n,
        'Low': [np.nan] * n,
        'Close': [np.nan] * n,
        'Volume': [np.nan] * n,
        'Dividends': [np.nan] * n,
        'Stock Splits': [np.nan] * n,
    },
    index=dt_list,
)
df0.index.name = 'Datetime'
df0
# Out:
#                            Open  High  Low  Close  Volume  Dividends  \
# Datetime
# 2024-09-12 09:00:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2024-09-12 09:01:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2024-09-12 09:02:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2024-09-12 09:03:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2024-09-12 09:04:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# ...                         ...   ...  ...    ...     ...        ...
# 2024-09-12 14:55:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2024-09-12 14:56:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2024-09-12 14:57:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2024-09-12 14:58:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2024-09-12 14:59:00+09:00   NaN   NaN  NaN    NaN     NaN        NaN
#
#                            Stock Splits
# Datetime
# 2024-09-12 09:00:00+09:00           NaN
# 2024-09-12 09:01:00+09:00           NaN
# 2024-09-12 09:02:00+09:00           NaN
# 2024-09-12 09:03:00+09:00           NaN
# 2024-09-12 09:04:00+09:00           NaN
# ...                                 ...
# 2024-09-12 14:55:00+09:00           NaN
# 2024-09-12 14:56:00+09:00           NaN
# 2024-09-12 14:57:00+09:00           NaN
# 2024-09-12 14:58:00+09:00           NaN
# 2024-09-12 14:59:00+09:00           NaN
#
# [301 rows x 7 columns]

# %%
mpf.plot(df0, type='candle', style='binance', ylabel='USD - JPY', figratio=(12, 4))
# Out:
# /home/bitwalk/MyProjects/stock-explorer/venv/lib64/python3.12/site-packages/mplfinance/plotting.py:592: RuntimeWarning: All-NaN slice encountered
#   miny = np.nanmin(_lows)
# /home/bitwalk/MyProjects/stock-explorer/venv/lib64/python3.12/site-packages/mplfinance/plotting.py:593: RuntimeWarning: All-NaN slice encountered
#   maxy = np.nanmax(_highs)

# %%
dt_current = df.iloc[0:1].index
dt_current
# Out:
# DatetimeIndex(['2024-09-11 09:00:00+09:00'], dtype='datetime64[ns, Asia/Tokyo]', name='Datetime', freq=None)

# %%
df.loc[dt_current]
# Out:
#                               Open     High      Low    Close  Volume  \
# Datetime
# 2024-09-11 09:00:00+09:00  22230.0  22365.0  22170.0  22340.0       0
#
#                            Dividends  Stock Splits
# Datetime
# 2024-09-11 09:00:00+09:00        0.0           0.0

# %%
df0.loc[dt_current] = df.loc[dt_current]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df0.loc[dt_current] = df.loc[dt_current]
#
# File ~/MyProjects/stock-explorer/venv/lib64/python3.12/site-packages/pandas/core/indexing.py:907, in _LocationIndexer.__setitem__(self, key, value)
#     905     maybe_callable = com.apply_if_callable(key, self.obj)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907 indexer = self._get_setitem_indexer(key)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/MyProjects/stock-explorer/venv/lib64/python3.12/site-packages/pandas/core/indexing.py:780, in _LocationIndexer._get_setitem_indexer(self, key)
#     776 if isinstance(key, range):
#     777     # GH#45479 test_loc_setitem_range_key
#     778     key = list(key)
# --> 780 return self._convert_to_indexer(key, axis=0)
#
# File ~/MyProjects/stock-explorer/venv/lib64/python3.12/site-packages/pandas/core/indexing.py:1522, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1520         return key
#    1521     else:
# -> 1522         return self._get_listlike_indexer(key, axis)[1]
#    1523 else:
#    1524     try:
#
# File ~/MyProjects/stock-explorer/venv/lib64/python3.12/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/MyProjects/stock-explorer/venv/lib64/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/MyProjects/stock-explorer/venv/lib64/python3.12/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [DatetimeIndex(['2024-09-11 09:00:00+09:00'], dtype='datetime64[ns, Asia/Tokyo]', name='Datetime', freq=None)] are in the [index]"

# %%
df0
# Out:
#                               Open     High      Low    Close  Volume  \
# Datetime
# 2024-09-11 09:00:00+09:00  22230.0  22365.0  22170.0  22340.0     0.0
# 2024-09-11 09:01:00+09:00      NaN      NaN      NaN      NaN     NaN
# 2024-09-11 09:02:00+09:00      NaN      NaN      NaN      NaN     NaN
# 2024-09-11 09:03:00+09:00      NaN      NaN      NaN      NaN     NaN
# 2024-09-11 09:04:00+09:00      NaN      NaN      NaN      NaN     NaN
# ...                            ...      ...      ...      ...     ...
# 2024-09-11 14:55:00+09:00      NaN      NaN      NaN      NaN     NaN
# 2024-09-11 14:56:00+09:00      NaN      NaN      NaN      NaN     NaN
# 2024-09-11 14:57:00+09:00      NaN      NaN      NaN      NaN     NaN
# 2024-09-11 14:58:00+09:00      NaN      NaN      NaN      NaN     NaN
# 2024-09-11 14:59:00+09:00      NaN      NaN      NaN      NaN     NaN
#
#                            Dividends  Stock Splits
# Datetime
# 2024-09-11 09:00:00+09:00        0.0           0.0
# 2024-09-11 09:01:00+09:00        NaN           NaN
# 2024-09-11 09:02:00+09:00        NaN           NaN
# 2024-09-11 09:03:00+09:00        NaN           NaN
# 2024-09-11 09:04:00+09:00        NaN           NaN
# ...                              ...           ...
# 2024-09-11 14:55:00+09:00        NaN           NaN
# 2024-09-11 14:56:00+09:00        NaN           NaN
# 2024-09-11 14:57:00+09:00        NaN           NaN
# 2024-09-11 14:58:00+09:00        NaN           NaN
# 2024-09-11 14:59:00+09:00        NaN           NaN
#
# [301 rows x 7 columns]

# %%
mpf.plot(df0, type='candle', style='binance', ylabel='USD - JPY', figratio=(12, 4))

# %%
for t in df.index[(df.index <= dt_end_1) | (df.index >= dt_start_2)]:
    df0.loc[t] = df.loc[t]
df0
# Out:
#                               Open     High      Low    Close   Volume  \
# Datetime
# 2024-09-11 09:00:00+09:00  22230.0  22365.0  22170.0  22340.0      0.0
# 2024-09-11 09:01:00+09:00  22340.0  22570.0  22340.0  22525.0  75200.0
# 2024-09-11 09:02:00+09:00  22540.0  22650.0  22530.0  22615.0  55500.0
# 2024-09-11 09:03:00+09:00  22615.0  22630.0  22465.0  22480.0  53500.0
# 2024-09-11 09:04:00+09:00  22475.0  22510.0  22400.0  22465.0  55200.0
# ...                            ...      ...      ...      ...      ...
# 2024-09-11 14:55:00+09:00  22220.0  22245.0  22215.0  22240.0  18800.0
# 2024-09-11 14:56:00+09:00  22245.0  22270.0  22220.0  22230.0  35100.0
# 2024-09-11 14:57:00+09:00  22225.0  22240.0  22210.0  22235.0  23300.0
# 2024-09-11 14:58:00+09:00  22235.0  22235.0  22210.0  22225.0  20500.0
# 2024-09-11 14:59:00+09:00  22220.0  22235.0  22175.0  22175.0  48000.0
#
#                            Dividends  Stock Splits
# Datetime
# 2024-09-11 09:00:00+09:00        0.0           0.0
# 2024-09-11 09:01:00+09:00        0.0           0.0
# 2024-09-11 09:02:00+09:00        0.0           0.0
# 2024-09-11 09:03:00+09:00        0.0           0.0
# 2024-09-11 09:04:00+09:00        0.0           0.0
# ...                              ...           ...
# 2024-09-11 14:55:00+09:00        0.0           0.0
# 2024-09-11 14:56:00+09:00        0.0           0.0
# 2024-09-11 14:57:00+09:00        0.0           0.0
# 2024-09-11 14:58:00+09:00        0.0           0.0
# 2024-09-11 14:59:00+09:00        0.0           0.0
#
# [301 rows x 7 columns]

# %%
mpf.plot(df0, type='candle', style='binance', ylabel='USD - JPY', figratio=(12, 4))

# %%
dt_now < dt_start_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dt_now < dt_start_1
#
# NameError: name 'dt_now' is not defined
