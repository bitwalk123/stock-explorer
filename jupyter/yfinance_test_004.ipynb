# %%
import datetime as dt
import yfinance as yf
#yf.set_tz_cache_location('Asia/Tokyo')

# %%
ticker = yf.Ticker('USDJPY=X')

# %%
end = dt.date.today()
delta = dt.timedelta(days=1)
start = end - delta

ticker.history(start=start, end=end, interval='1m')
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-07-31 00:00:00+01:00  152.875000  152.934998  152.860992  152.869003
# 2024-07-31 00:01:00+01:00  152.862000  152.953003  152.862000  152.953003
# 2024-07-31 00:02:00+01:00  152.955994  152.972000  152.912003  152.949997
# 2024-07-31 00:03:00+01:00  152.944000  152.973999  152.906998  152.919998
# 2024-07-31 00:04:00+01:00  152.921997  152.931000  152.882996  152.886002
# ...                               ...         ...         ...         ...
# 2024-07-31 23:54:00+01:00  150.126999  150.141006  150.093002  150.139008
# 2024-07-31 23:55:00+01:00  150.138000  150.162003  150.110992  150.143005
# 2024-07-31 23:56:00+01:00  150.141006  150.192001  150.113007  150.160995
# 2024-07-31 23:57:00+01:00  150.158005  150.173004  150.136993  150.151993
# 2024-07-31 23:58:00+01:00  150.149994  150.156006  150.132004  150.151993
#
#                            Volume  Dividends  Stock Splits
# Datetime
# ...

# %%
ticker.history_metadata
# Out:
# {'currency': 'JPY',
#  'symbol': 'JPY=X',
#  'exchangeName': 'CCY',
#  'fullExchangeName': 'CCY',
#  'instrumentType': 'CURRENCY',
#  'firstTradeDate': 846633600,
#  'regularMarketTime': 1722468344,
#  'hasPrePostMarketData': False,
#  'gmtoffset': 3600,
#  'timezone': 'BST',
#  'exchangeTimezoneName': 'Europe/London',
#  'regularMarketPrice': 150.06,
#  'fiftyTwoWeekHigh': 150.318,
#  'fiftyTwoWeekLow': 149.777,
#  'regularMarketDayHigh': 150.318,
#  'regularMarketDayLow': 149.777,
#  'regularMarketVolume': 0,
#  'chartPreviousClose': 152.67,
#  'previousClose': 149.919,
#  'scale': 4,
#  'priceHint': 4,
#  'currentTradingPeriod': {'pre': {'timezone': 'BST',
#    'end': 1722466800,
#    'start': 1722466800,
#    'gmtoffset': 3600},
#   'regular': {'timezone': 'BST',
#    'end': 1722553140,
#    'start': 1722466800,
#    'gmtoffset': 3600},
#   'post': {'timezone': 'BST',
#    'end': 1722553140,
#    'start': 1722553140,
#    'gmtoffset': 3600}},
# ...
