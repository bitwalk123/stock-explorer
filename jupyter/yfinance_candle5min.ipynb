# %%
import datetime as dt
import mplfinance as mpf
import yfinance as yf

d = 5
start = dt.date(2024, 1, d)
end = dt.date(2024, 1, d + 1)

ticker = '8035.T' # 東京エレクトロン
df = yf.download(ticker, start, end, interval='5m')
mpf.plot(df, type='candle', style='binance', figratio=(12, 4))
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2024-01-05 09:00:00+09:00  24000.0  24015.0  23680.0  23695.0    23695.0
# 2024-01-05 09:05:00+09:00  23690.0  23755.0  23670.0  23750.0    23750.0
# 2024-01-05 09:10:00+09:00  23750.0  23920.0  23745.0  23900.0    23900.0
# 2024-01-05 09:15:00+09:00  23905.0  24025.0  23880.0  23980.0    23980.0
# 2024-01-05 09:20:00+09:00  23985.0  24060.0  23955.0  23970.0    23970.0
# ...                            ...      ...      ...      ...        ...
# 2024-01-05 14:35:00+09:00  24210.0  24215.0  24190.0  24190.0    24190.0
# 2024-01-05 14:40:00+09:00  24195.0  24195.0  24150.0  24185.0    24185.0
# 2024-01-05 14:45:00+09:00  24180.0  24185.0  24165.0  24175.0    24175.0
# 2024-01-05 14:50:00+09:00  24180.0  24195.0  24150.0  24150.0    24150.0
# 2024-01-05 14:55:00+09:00  24155.0  24175.0  24150.0  24165.0    24165.0
#
#                            Volume
# Datetime
# 2024-01-05 09:00:00+09:00       0
# 2024-01-05 09:05:00+09:00  167100
# 2024-01-05 09:10:00+09:00  128800
# 2024-01-05 09:15:00+09:00  247300
# 2024-01-05 09:20:00+09:00  136900
# ...                           ...
# 2024-01-05 14:35:00+09:00   37400
# 2024-01-05 14:40:00+09:00   76300
# 2024-01-05 14:45:00+09:00   37200
# 2024-01-05 14:50:00+09:00   66800
# 2024-01-05 14:55:00+09:00   72500
#
# [62 rows x 6 columns]

# %%
[int(dt.timestamp()) for dt in list(df.index)][0]
# Out:
# 1705017840

# %%
dt.datetime.fromtimestamp(1705017840)
# Out:
# datetime.datetime(2024, 1, 12, 9, 4)
