# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import robust_scale
from scipy.stats import norm

# %%
def robust_z(x):
    coefficient = norm.ppf(0.75)-norm.ppf(0.25)
    robust_z_score = robust_scale(x)*coefficient

    return robust_z_score

# %%
X = pd.Series([ 1., -2.,  2., -2.,  1.,  3., 4.,  1., -2.])
X
# Out:
# 0    1.0
# 1   -2.0
# 2    2.0
# 3   -2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    1.0
# 8   -2.0
# dtype: float64

# %%
robust_scale(X)
# Out:
# array([ 0.  , -0.75,  0.25, -0.75,  0.  ,  0.5 ,  0.75,  0.  , -0.75])

# %%
x_array = np.array(X).reshape(-1, 1)
x_array
# Out:
# array([[ 1.],
#        [-2.],
#        [ 2.],
#        [-2.],
#        [ 1.],
#        [ 3.],
#        [ 4.],
#        [ 1.],
#        [-2.]])

# %%
scaler = RobustScaler().fit(x_array)
scaler
# Out:
# RobustScaler()

# %%
scaler.transform(x_array)
# Out:
# array([[ 0.  ],
#        [-0.75],
#        [ 0.25],
#        [-0.75],
#        [ 0.  ],
#        [ 0.5 ],
#        [ 0.75],
#        [ 0.  ],
#        [-0.75]])

# %%
data = np.concatenate((np.random.uniform(low=5.0, high=10.0, size=100),
                       np.random.normal(loc=5.0, scale=1.0, size=100)))
data
# Out:
# array([6.38531735, 9.92050562, 8.54420587, 9.38318967, 7.19128385,
#        8.70474248, 8.17236124, 5.67594583, 7.83215406, 8.12995022,
#        9.1904848 , 5.99622048, 5.49368161, 9.47820041, 9.18837786,
#        6.32585507, 5.10792007, 8.40409199, 7.74182017, 5.53208607,
#        8.03806561, 5.70127905, 6.60295662, 8.4397091 , 8.9611865 ,
#        6.05713824, 9.74321142, 9.42598489, 5.37668859, 9.61201221,
#        5.35335112, 9.60602791, 6.56626149, 7.01345949, 9.09161995,
#        6.35602027, 5.43204047, 7.17429079, 6.35063186, 7.79644074,
#        5.50777684, 8.34217889, 6.07100019, 7.99674013, 8.14880298,
#        5.03669027, 9.30244301, 8.3790243 , 8.4504228 , 9.73679101,
#        9.43321311, 5.62052781, 5.84019716, 6.89253843, 7.17040865,
#        8.66436264, 7.50507832, 7.21636602, 5.6294987 , 5.00187596,
#        7.99717763, 9.96320434, 6.26628256, 7.32798908, 8.75317102,
#        9.35859884, 5.39601367, 6.83027537, 9.56819113, 5.56813748,
#        8.23135174, 5.20321738, 8.84641332, 6.18167274, 6.33647339,
#        5.84938851, 8.20138866, 9.50693593, 9.75661693, 9.65247006,
#        9.32584117, 9.23178693, 9.03612007, 9.3155618 , 6.83172949,
#        5.80554533, 6.36601157, 9.36760202, 6.69112833, 8.2324233 ,
#        9.74895026, 9.16260214, 5.30047923, 9.34994386, 7.62805585,
#        7.67980499, 6.5476971 , 5.18829083, 9.698795  , 5.38604649,
#        4.28367404, 6.72579872, 4.5161919 , 5.82163938, 4.81273512,
#        4.60652523, 4.26908164, 3.86163247, 4.93877261, 4.64112696,
#        6.10636321, 4.80152598, 6.11693175, 4.41355703, 4.12233928,
#        4.36729643, 4.33294088, 4.90987858, 6.39773567, 3.82114308,
#        3.55382752, 4.74225859, 5.40488259, 5.42778975, 3.8295451 ,
#        5.33163829, 6.1485554 , 4.61248452, 4.51837494, 5.4224559 ,
#        5.76377543, 4.3145778 , 3.93238473, 5.68814953, 3.98812097,
#        5.96162201, 4.62231529, 5.51637966, 4.76502149, 5.42453369,
#        4.45004595, 4.96935738, 5.8735312 , 5.33198258, 5.27718081,
#        4.06272716, 4.68162903, 4.01883729, 4.57815691, 5.29663311,
#        5.46950587, 5.26059351, 3.95889853, 4.74489155, 5.32804394,
#        4.89367854, 5.05398481, 6.70617359, 4.53138951, 5.60844595,
#        5.13390184, 4.52889837, 4.8756296 , 5.39069372, 5.80171508,
#        5.97887021, 4.40882155, 6.00012204, 4.9072962 , 5.84434444,
#        6.74023074, 3.67163394, 3.41804299, 4.72599003, 4.94937247,
#        5.10841161, 6.39900761, 6.16677896, 4.96107901, 4.27360024,
#        3.27770224, 4.36216549, 6.59094205, 2.3730661 , 4.50006289,
#        5.0069867 , 4.61778725, 6.05474367, 6.44066038, 4.30337377,
#        5.09403013, 4.59677448, 5.53819505, 5.83734682, 4.57439805,
#        4.38549129, 4.73641442, 6.38931934, 4.6595736 , 4.06660155])
