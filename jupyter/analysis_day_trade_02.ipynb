# %%
import os

os.chdir('../')
os.getcwd()
# Out:
# '/home/bitwalk/MyProjects/stock-explorer'

# %%
dir_path = 'cache'
files = os.listdir(dir_path)
#files

# %%
import pandas as pd

pkl = '8035.T_2024-04-30_2024-05-01_1m.pkl'
file = os.path.join(dir_path, pkl)    
df = pd.read_pickle(file)
df
# Out:
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2024-04-30 09:03:00+09:00  35000.0  35050.0  34900.0  34900.0    34900.0
# 2024-04-30 09:04:00+09:00  34920.0  35050.0  34880.0  34990.0    34990.0
# 2024-04-30 09:05:00+09:00  34990.0  35170.0  34990.0  35120.0    35120.0
# 2024-04-30 09:06:00+09:00  35120.0  35250.0  35080.0  35240.0    35240.0
# 2024-04-30 09:07:00+09:00  35220.0  35320.0  35210.0  35240.0    35240.0
# ...                            ...      ...      ...      ...        ...
# 2024-04-30 14:55:00+09:00  34900.0  34910.0  34890.0  34910.0    34910.0
# 2024-04-30 14:56:00+09:00  34920.0  34940.0  34920.0  34940.0    34940.0
# 2024-04-30 14:57:00+09:00  34950.0  34960.0  34940.0  34950.0    34950.0
# 2024-04-30 14:58:00+09:00  34960.0  34990.0  34960.0  34970.0    34970.0
# 2024-04-30 14:59:00+09:00  34970.0  35110.0  34970.0  35110.0    35110.0
#
#                            Volume
# Datetime
# 2024-04-30 09:03:00+09:00       0
# ...

# %%
df2 = df.loc['2024-04-30 09:00:00' : '2024-04-30 11:00:00']
df2
# Out:
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2024-04-30 09:03:00+09:00  35000.0  35050.0  34900.0  34900.0    34900.0
# 2024-04-30 09:04:00+09:00  34920.0  35050.0  34880.0  34990.0    34990.0
# 2024-04-30 09:05:00+09:00  34990.0  35170.0  34990.0  35120.0    35120.0
# 2024-04-30 09:06:00+09:00  35120.0  35250.0  35080.0  35240.0    35240.0
# 2024-04-30 09:07:00+09:00  35220.0  35320.0  35210.0  35240.0    35240.0
# ...                            ...      ...      ...      ...        ...
# 2024-04-30 10:56:00+09:00  35280.0  35290.0  35260.0  35270.0    35270.0
# 2024-04-30 10:57:00+09:00  35260.0  35260.0  35190.0  35220.0    35220.0
# 2024-04-30 10:58:00+09:00  35230.0  35240.0  35230.0  35230.0    35230.0
# 2024-04-30 10:59:00+09:00  35230.0  35250.0  35220.0  35250.0    35250.0
# 2024-04-30 11:00:00+09:00  35260.0  35270.0  35250.0  35260.0    35260.0
#
#                            Volume
# Datetime
# 2024-04-30 09:03:00+09:00       0
# ...

# %%
import matplotlib.pyplot as plt
import mplfinance as mpf

plt.rcParams["figure.figsize"] = (10, 5)
fig, ax = plt.subplots()

mpf.plot(
    df2,
    #type='line',
    type='candle',
    style='binance',
    ax=ax
)
plt.grid(linestyle=':')
plt.subplots_adjust(left=0.06, right=0.995, bottom=0.2, top=0.93)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (10, 5)
fig, ax = plt.subplots()

ax.plot(
    df2['Close']
)
plt.grid(linestyle=':')
plt.subplots_adjust(left=0.06, right=0.995, bottom=0.2, top=0.93)
plt.show()

# %%
df3 = pd.DataFrame({'Close': list(df.iloc[0:60]['Close'])}, index=list(range(60)))
fig, ax = plt.subplots()

ax.plot(
    df3
)
plt.grid(linestyle=':')
plt.show()
