# %%
import sys
path_up = '..'
if not path_up in sys.path:
    sys.path.append(path_up)
    
import matplotlib.pyplot as plt
import pandas as pd

from modules.psar import RealtimePSAR

# %%
name_excel = '../excel/trader_20250526.xlsx'
df = pd.read_excel(name_excel, sheet_name='tick_7011')
df
# Out:
#                 Time  Price
# 0      1748217600000   3250
# 1      1748217601000   3250
# 2      1748217602000   3250
# 3      1748217603000   3249
# 4      1748217604000   3249
# ...              ...    ...
# 16695  1748240695000   3196
# 16696  1748240696000   3196
# 16697  1748240697000   3196
# 16698  1748240698000   3196
# 16699  1748240699000   3196
#
# [16700 rows x 2 columns]

# %%
list_trend = list()
list_psar = list()

psar = RealtimePSAR()
for y in df['Price']:
    ret = psar.add(y)
    list_psar.append(ret.psar)
    list_trend.append(ret.trend)

df['Trend'] = list_trend
df['PSAR'] = list_psar

df_bull = df[df['Trend'] == 1][['Time', 'PSAR']]
df_bear = df[df['Trend'] == -1][['Time', 'PSAR']]

# %%
fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(df["Time"], df["Price"], color="black", linewidth=0.5)
ax.scatter(x=df_bull['Time'], y=df_bull['PSAR'], s=5, c="red")
ax.scatter(x=df_bear['Time'], y=df_bear['PSAR'], s=5, c="blue")
ax.grid()
plt.show()
